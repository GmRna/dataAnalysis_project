# %%
import pandas as pd
import numpy as np

# %%
income = pd.read_csv('05_구_상권배후지_소득소비.csv', encoding='cp949')
income[income['기준 년 코드']==2021]
# Out:
#       기준 년 코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명  월_평균_소득_금액  \
# 0        2021         1        A       골목상권  1000193   왕산로43길     2729716
# 1        2021         1        A       골목상권  1000298   정릉로27길     3355209
# 2        2021         1        A       골목상권  1000297   정릉로26길     3338064
# 3        2021         1        A       골목상권  1000296   장위로50길     2416795
# 4        2021         1        A       골목상권  1000295    장월로1길     2956757
# ...       ...       ...      ...        ...      ...      ...         ...
# 4035     2021         4        A       골목상권  1000735     국사봉길     2605976
# 4036     2021         4        A       골목상권  1000734    국사봉2길     2748926
# 4037     2021         4        A       골목상권  1000733    국사봉1길     2682472
# 4038     2021         4        A       골목상권  1000732    영신로9길     2415422
# 4039     2021         4        A       골목상권  1000731  영등포로84길     2806083
#
#       소득_구간_코드       지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# ...

# %%
apt = pd.read_csv('05_구_상권배후지_아파트.csv', encoding='cp949')
apt[apt['기준_년_코드']==2021].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4036 entries, 0 to 4035
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   기준_년_코드                 4036 non-null   int64
#  1   기준_분기_코드                4036 non-null   int64
#  2   상권_구분_코드                4036 non-null   object
#  3   상권_구분_코드_명              4036 non-null   object
#  4   상권_코드                   4036 non-null   int64
#  5   상권_코드_명                 4036 non-null   object
#  6   아파트_단지_수                4036 non-null   int64
#  7   아파트_면적_66_제곱미터_미만_세대_수  4036 non-null   int64
#  8   아파트_면적_66_제곱미터_세대_수     4036 non-null   int64
#  9   아파트_면적_99_제곱미터_세대_수     4036 non-null   int64
#  10  아파트_면적_132_제곱미터_세대_수    4036 non-null   int64
#  11  아파트_면적_165_제곱미터_세대_수    4036 non-null   int64
#  12  아파트_가격_1_억_미만_세대_수      4036 non-null   int64
#  13  아파트_가격_1_억_세대_수         4036 non-null   int64
# ...

# %%
infra = pd.read_csv('05_구_상권배후지_집객시설.csv')
infra[infra['기준_년_코드']==2021].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4040 entries, 24240 to 28279
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기준_년_코드     4040 non-null   int64
#  1   기준_분기_코드    4040 non-null   int64
#  2   상권_구분_코드    4040 non-null   object
#  3   상권_구분_코드_명  4040 non-null   object
#  4   상권_코드       4040 non-null   int64
#  5   상권_코드_명     4040 non-null   object
#  6   집객시설_수      4040 non-null   int64
#  7   관공서_수       3915 non-null   float64
#  8   은행_수        3607 non-null   float64
#  9   종합병원_수      465 non-null    float64
#  10  일반_병원_수     1645 non-null   float64
#  11  약국_수        4010 non-null   float64
#  12  유치원_수       2450 non-null   float64
#  13  초등학교_수      3132 non-null   float64
#  14  중학교_수       1971 non-null   float64
#  15  고등학교_수      1532 non-null   float64
#  16  대학교_수       935 non-null    float64
#  17  백화점_수       44 non-null     float64
# ...
